# %%
num=2 
while num <4:
    print("odd number")
    num = num +1
# Out:
# odd number
# odd number

# %%
counter=0
while counter <5:
    print("loop counter",counter)
    counter = counter+1
# Out:
# loop counter 0
# loop counter 1
# loop counter 2
# loop counter 3
# loop counter 4

# %%
counter=6
while counter >0:
    print("loop counter",counter)
    counter = counter -1
# Out:
# loop counter 6
# loop counter 5
# loop counter 4
# loop counter 3
# loop counter 2
# loop counter 1

# %%
counter=1
while counter <=4:
    print("primary number",counter)
    counter = counter +1
# Out:
# primary number 1
# primary number 2
# primary number 3
# primary number 4
